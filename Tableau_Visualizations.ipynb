# %% [markdown]
# Q9. Explain why different charts were used for different business questions in this analysis.
#
# ->
# | Task | Chart Type           | Business Question           | Why This Chart Works                                          |
# | ---- | -------------------- | --------------------------- | ------------------------------------------------------------- |
# | 1    | Bar Chart            | Category sales comparison   | Bars excel at ranking/comparing discrete categories by length |
# | 2    | Line Chart           | Monthly sales trends        | Lines show time progression, peaks/valleys clearly            |
# | 3    | Pie Chart            | Regional % contribution     | Slices show proportions/parts of whole intuitively            |
# | 4    | Scatter Plot         | Sales vs Profit correlation | X-Y reveals relationships, outliers (losses)                  |
# | 5    | Line (Running Total) | Cumulative growth           | Cumulative line shows overall trajectory                      |
# | 6    | Heatmap              | Category × Region matrix    | Color intensity compares cross-dimensions                     |
# | 7    | Bubble Scatter       | Sales/Profit/Quantity       | Size adds 3rd dimension to X-Y analysis                       |
# | 8    | Dashboard            | Executive summary           | Multiple viz + filters = interactive overview                 |
#
# Q10. Summarize two key insights from your dashboard and explain how they can help management make better decisions.
#
# -> Insight 1: Technology category generates highest sales (45% of total revenue) but lowest profit margins (-2% margin vs. Office Supplies +15%)
#
# Insight 2: Central region delivers 35% of total sales ($325K) - 12 points above other regions
#
# | Insight                                           | Business Decision Impact                                                         |
# | ------------------------------------------------- | -------------------------------------------------------------------------------- |
# | Technology dominates sales but low profit margins | Review pricing strategy; negotiate better supplier costs for Technology products |
# | Central region leads sales (35% share)            | Allocate 50% marketing budget to Central; expand inventory there                 |
